# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('params_sub.json', 'r', encoding='utf-8') as f:
    parameters = json.load(f)
print(parameters[0]) ## 잘 되는 지 예시
# Out:
# {'subj': 1, 'q_alpha': 0.0, 'q_beta': 0.9914592762531507, 'vs_alpha_plus': 1.0, 'vs_alpha_minus': 0.0, 'vs_beta': 1.1080371525012784, 'vs_w': 0.7595915137016236, 'nll_q': 138.62943611158894, 'nll_vs': 136.275148256208}

# %%
df = pd.DataFrame(parameters)
df.head()
# Out:
#    subj   q_alpha      q_beta  vs_alpha_plus  vs_alpha_minus     vs_beta  \
# 0     1  0.000000    0.991459       1.000000        0.000000    1.108037
# 1     2  0.458580    0.161251       0.000196        0.000849  788.531776
# 2     3  0.000000    0.991505       0.000231        0.000000  256.673849
# 3     4  0.000263  186.616091       0.000941        0.000277  274.724726
# 4     5  0.239523    0.505671       0.098402        0.007585    6.206145
#
#        vs_w       nll_q      nll_vs
# 0  0.759592  138.629436  136.275148
# 1  0.899428  137.259735  134.363024
# 2  1.000000  138.629436  129.936261
# 3  0.280123  136.578441  136.475792
# 4  0.163626  134.904281  137.278152

# %%
plot_standard = ['q_alpha', 'q_beta', 'vs_alpha_plus', 'vs_alpha_minus', 'vs_beta', 'vs_w', 'nll_q', 'nll_vs']
#각 값 별로 분포 확인
for ps in plot_standard:
    plt.title(f"log_{ps}")
    plt.hist(np.log10(df[ps]+1e-12), bins = 30)
    plt.show()
    plt.title(f"{ps}")
    plt.hist(df[ps], bins = 15)
    plt.show()
